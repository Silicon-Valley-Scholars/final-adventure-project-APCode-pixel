# %%
import time
gold=0
inventory=[]
def final_chest(action):
  inventory.append("Magic Key")
  inventory.append("Map")
  return action+ character+" discovers and opens the final chest and finds: 35 gold, a Magic Key, and a map!"

character=input("Player Name Here: ")
print("One long, boring, summer day, you decide to learn how to solve a Rubik's cube.")
print(character, "embarks on a breathtaking journey to learn to solve their first cube.", character, "will have to collect gold, make choices, and find the master of cubing.")
print("First,", character, "will have to obtain a Rubik's cube by collecting gold and finding a store.")
choice1=input("Pick a path, A or B:").lower()
if choice1=="a":
  gold=gold+5
  print(character, "obtained 5 gold!", character, "has", gold, "gold in total now!")
if choice1=="b":
  gold=gold+10
  print(character, "obtained 10 gold!", character, "has", gold, "gold in total now!")
print("Now", character, "finds two tunnels, and must pick one.")
choice2=input("Pick a tunnel, A or B:").lower()
if choice2=="a":
  gold=gold+10
  print(character, "obtained 10 gold!", character, "has", gold, "gold in total now!")
if choice2=="b":
  gold=gold+5
  print(character, "obtained 5 gold!", character, "has", gold, "gold in total now!")
print(character, "is now at a store, and needs to pick what to buy.")
store1=input(f"Choose something to buy!: A Rubik's cube for 10 gold, (type Cube), or a bike that lets you take shortcuts for 15 gold, (type Bike). Your gold: {gold} :").lower()

if store1=="cube":
  gold=gold-10
  inventory.append("Rubik's Cube")
  print(character, "now has a Rubik's cube, and continues their journey!")
  print(character, "continues on the normal route, and finds two treasure chests.")
  choice3=input("Pick a chest, A or B:").lower()
  if choice3=="a":
    gold=gold+20
    print(character, "obtained 20 gold!", character, "has", gold, "gold in total now!")
  if choice3=="b":
    gold=gold+15
    print(character, "obtained 15 gold!", character, "has", gold, "gold in total now!")
  print(character, "continues traveling, and finds a lake and a boat shop.", character, "can choose to buy a boat and cross the lake, or continue normally and save gold.")
  store2=input("Choose to buy a boat, (15 gold) which will take you to a very close spot to the master of cubing, (type Boat), or to continue normally, (type Normal):").lower()
  if store2=="boat":
    gold=gold-15
    inventory.append("Boat")
    print(character, "buys a boat, and crosses the lake.", character, "is almost at the master of cubing!")
    print(final_chest("After crossing the lake, "))
    gold=gold+35
  if store2=="normal":
    print(character, "continues normally, and saves gold.")
    print(character, "keeps traveling and finds 5 gold on the way.")
    gold=gold+5
    print(final_chest("Now, "))
    gold=gold+35

if gold>=15:
  if store1=="bike":
    gold=gold-15
    inventory.append("Bike")
    print(character, "now has a Bike, and continues their journey!")
    print(character, "takes a shortcut through the mountains, and finds two trails.")
    choice4=input("Pick a trail, A or B:").lower()
    if choice4=="a":
      gold=gold+15
      print(character, "obtained 15 gold!", character, "has", gold, "gold in total now!")
    if choice4=="b":
      gold=gold+10
      print(character, "obtained 10 gold!", character, "has", gold, "gold in total now!")
    print(character, "comes across a mountain's steep cliff, and can choose to bike down the rough path, and possibly lose a bit of gold, or continue on the designated route.")
    choice5=input("Would you like to bike down the rough path as a shortcut (type Shortcut), or continue normally, (type Normal):").lower()
    if choice5=="shortcut":
      gold=gold-5
      print(character, "lost 5 gold due to the intense speed and winds while going down, but is almost at the master of cubing!")
      print(character, "finds a store selling Rubik's cubes, and buys one.")
      inventory.append("Rubik's Cube")
      print(final_chest("After biking down the steep cliff and buying a cube, "))
      gold=gold+35
    if choice5=="normal":
      print(character, "continues normally, and keeps their gold.")
      print(character, "finds a store selling Rubik's cubes, and buys one.")
      inventory.append("Rubik's Cube")
      print(character, "keeps traveling and finds 5 gold on the way.")
      gold=gold+5
      print(final_chest("Now, "))
      gold=gold+35

print(character, "takes a look at the map and sees that it leads them to a far-off place, and decides that it must be the master of cubing's location, and follows it.")
print("Once", character, "reaches the destination, they see a Magic Door!", character, "decides to use the Magic key they got earlier to open the door.")
print(character, "opens the Magic Door and goes inside, then sees the person they had been looking for this whole time: The Master of Cubing.")
print(character, "walks up to the Master of Cubing and asks if the Master can teach", character, "how to solve a Rubik's cube, and the Master says yes.")

print(character, "learns how to solve the Rubik's cube, and becomes amazingly good at it.")
time.sleep(4)
print(character, "teaches even more people how to solve the Rubik's cube, and everyone appreciates it.")
time.sleep(4)
print("Your final inventory:")
for each in inventory:
  print("-", each)
print("-", gold, "gold")
print("Thank you,", character, ", for playing!")
# Out:
# Player Name Here: Anay
# One long, boring, summer day, you decide to learn how to solve a Rubik's cube.
# Anay embarks on a breathtaking journey to learn to solve their first cube. Anay will have to collect gold, make choices, and find the master of cubing.
# First, Anay will have to obtain a Rubik's cube by collecting gold and finding a store.
# Pick a path, A or B:b
# Anay obtained 10 gold! Anay has 10 gold in total now!
# Now Anay finds two tunnels, and must pick one.
# Pick a tunnel, A or B:a
# Anay obtained 10 gold! Anay has 20 gold in total now!
# Anay is now at a store, and needs to pick what to buy.
# Choose something to buy!: A Rubik's cube for 10 gold, (type Cube), or a bike that lets you take shortcuts for 15 gold, (type Bike). Your gold: 20 :cube
# Anay now has a Rubik's cube, and continues their journey!
# Anay continues on the normal route, and finds two treasure chests.
# Pick a chest, A or B:B
# Anay obtained 15 gold! Anay has 25 gold in total now!
# ...
